# %%
#Mount Google Drive

from google.colab import drive
drive.mount('/content/drive')
print("✅ Google Drive mounted!")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ✅ Google Drive mounted!

# %%
#Set Working Directory (os.chdir)

import os

os.chdir('/content/drive/MyDrive/Colab Notebooks/DeepLearningClass/FinalProject_HOATaskAuto')

print("📁 Current folder:", os.getcwd())
print("\nFiles found:")
for f in os.listdir():
    print(f"   • {f}")
# Out:
# 📁 Current folder: /content/drive/MyDrive/Colab Notebooks/DeepLearningClass/FinalProject_HOATaskAuto
#
# Files found:
#    • HOATaskAuto.ipynb
#    • config.yaml
#    • requirements.txt
#    • dataset.py
#    • model.py
#    • train.py
#    • evaluate.py
#    • inference.py
#    • demo.py
#    • README.md
#    • data
#    • __pycache__
#    • models

# %%
#Verify All Required Files
required_files = [
    "dataset.py",
    "model.py",
    "train.py",
    "evaluate.py",
    "inference.py",
    "demo.py",
    "config.yaml"
]

print("Checking required files...\n")
all_good = True
for f in required_files:
    if os.path.exists(f):
        print(f"  ✅  {f}")
    else:
        print(f"  ❌  {f}  ← NOT FOUND")
        all_good = False

print()
if all_good:
    print("🎉 All files found! Ready to run.")
else:
    print("⚠️  Some files missing. Please upload them to:")
    print("   MyDrive/Colab Notebooks/DeepLearningClass/FinalProject_HOATaskAuto")
# Out:
# Checking required files...
#
#   ✅  dataset.py
#   ✅  model.py
#   ✅  train.py
#   ✅  evaluate.py
#   ✅  inference.py
#   ✅  demo.py
#   ✅  config.yaml
#
# 🎉 All files found! Ready to run.

# %%
#Install Dependencies
# !pip install anthropic gradio pyyaml python-dotenv scikit-learn tqdm

# %%
#Set API key
import os
os.environ["ANTHROPIC_API_KEY"] = "your_anthropic_api_key_here"

# %%
#Upload files

import os

# Check all required files exist in the current folder
required_files = [
    "dataset.py",
    "model.py",
    "train.py",
    "evaluate.py",
    "inference.py",
    "demo.py",
    "config.yaml"
]

print("Checking files in current directory...\n")
all_good = True
for f in required_files:
    if os.path.exists(f):
        print(f"  ✅  {f}")
    else:
        print(f"  ❌  {f}  ← NOT FOUND")
        all_good = False

print()
if all_good:
    print("✅ All files found! Ready to run.")
else:
    print("⚠️  Some files are missing. Please upload them to the same folder as this notebook.")
# Out:
# Checking files in current directory...
#
#   ✅  dataset.py
#   ✅  model.py
#   ✅  train.py
#   ✅  evaluate.py
#   ✅  inference.py
#   ✅  demo.py
#   ✅  config.yaml
#
# ✅ All files found! Ready to run.

# %%
#Run dataset.py
# %run dataset.py
# Out:
# Generating HOA request dataset …
# Total samples  : 2000
# Label distribution:
# label
# Maintenance Request      560
# Dues & Payment           440
# Rule Violation Report    360
# Amenity Booking          300
# General Inquiry          200
# Complaint / Dispute      140
#
# ✔  Train :  1399 samples
# ✔  Val   :   300 samples
# ✔  Test  :   301 samples
#
# Dataset saved to data/train.csv, data/val.csv, data/test.csv

# %%
#Run model.py
# %run model.py
# Out:
# Running smoke test on 6 samples...
#
#
# [DEBUG] Raw API response:
# {"category": "Maintenance Request", "confidence": 0.99, "reasoning": "Matches Maintenance Request pattern."}
#
# ✅ Expected : Maintenance Request
#    Got      : Maintenance Request  (99%)
#    Text     : The elevator in block 3 is making a loud noise.
#
#
# [DEBUG] Raw API response:
# {"category": "Dues & Payment", "confidence": 0.99, "reasoning": "Matches Dues & Payment pattern."}
#
# ✅ Expected : Dues & Payment
#    Got      : Dues & Payment  (99%)
#    Text     : I need to update my payment method on file.
#
#
# [DEBUG] Raw API response:
# {"category": "Rule Violation Report", "confidence": 0.97, "reasoning": "Reporting a neighbor's unauthorized installation is a rule violation report."}
#
# ✅ Expected : Rule Violation Report
#    Got      : Rule Violation Report  (97%)
#    Text     : My neighbor installed an unauthorized satellite dish.
#
#
# [DEBUG] Raw API response:
# ...

# %%
#Run train.py
# %run train.py
# Out:
# /content/drive/MyDrive/Colab Notebooks/DeepLearningClass/FinalProject_HOATaskAuto/train.py:56: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda x: x.sample(min(len(x), max_samples // 6), random_state=42))
# Loading validation set …
# Val samples: 300
# Initialising HOA Classifier (Claude Sonnet 4.6) …
#
# ────────────────────────────────────────────────────────────
#   Prompt Tuning Run  |  60 val samples
# ────────────────────────────────────────────────────────────
# Validating: 100%|██████████| 60/60 [02:21<00:00,  2.35s/it]
# Category                       Correct   Total  Accuracy
# ──────────────────────────────────────────────────────────
# ...

# %%
#Run evaluate.py
# %run evaluate.py
# Out:
# Loading test set …
# Test samples: 301
# Initialising HOA Classifier (Claude Sonnet 4.6) …
#
# ════════════════════════════════════════════════════════════
#   FINAL EVALUATION  |  301 test samples
# ════════════════════════════════════════════════════════════
#
# ⚠  Using held-out test set — do not re-run after reviewing results.
# Evaluating: 100%|██████████| 301/301 [11:57<00:00,  2.38s/it]
#                        precision    recall  f1-score   support
#
#       Amenity Booking     1.0000    0.8667    0.9286        45
#   Complaint / Dispute     1.0000    1.0000    1.0000        21
#        Dues & Payment     1.0000    1.0000    1.0000        66
#       General Inquiry     0.8333    1.0000    0.9091        30
#   Maintenance Request     1.0000    1.0000    1.0000        85
# Rule Violation Report     1.0000    1.0000    1.0000        54
#
#              accuracy                         0.9801       301
#             macro avg     0.9722    0.9778    0.9729       301
# ...

# %%
# Run Inference
# %run inference.py "The pool pump stopped working near building 3."
# Out:
# ────────────────────────────────────────────────────────────
#   INPUT      : The pool pump stopped working near building 3.
# ────────────────────────────────────────────────────────────
#   CATEGORY   : Maintenance Request
#   CONFIDENCE : 99%
#   REASONING  : The message reports a broken pool pump, which is a piece of equipment requiring repair, clearly falling under infrastructure/maintenance issues.
# ────────────────────────────────────────────────────────────
#   ROUTED TO  : Maintenance Team
#   PRIORITY   : High
#   NEXT STEP  : Create work order and schedule inspection within 48 hours.
# ────────────────────────────────────────────────────────────

# %%
#Lauch Demo
# %run demo.py
# Out:
# /content/drive/MyDrive/Colab Notebooks/DeepLearningClass/FinalProject_HOATaskAuto/demo.py:68: DeprecationWarning: The 'theme' parameter in the Blocks constructor will be removed in Gradio 6.0. You will need to pass 'theme' to Blocks.launch() instead.
#   with gr.Blocks(
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Note: opening Chrome Inspector may crash demo inside Colab notebooks.
# * To create a public link, set `share=True` in `launch()`.
